# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import category_encoders as ce
from sklearn.preprocessing import LabelEncoder

# %%
#attempting to predict whether or not some has paid off their loan or not
dataSet = pd.read_csv("bank-lending-prediction/lending_topredict.csv")

# %%
#data preprocessing 
print(dataSet.isnull().sum())
# Out:
# ID                               0
# requested_amnt                   0
# loan_duration                    0
# employment                   22223
# employment_length            20359
# race                             0
# reason_for_loan                  0
# extended_reason               4234
# annual_income                    0
# debt_to_income_ratio            96
# employment_verified              0
# public_bankruptcies            181
# zipcode                          0
# state                            0
# home_ownership_status            0
# delinquency_last_2yrs            0
# fico_score_range_low             0
# fico_score_range_high            0
# fico_inquired_last_6mths         0
# months_since_last_delinq    174434
# revolving_balance                0
# total_revolving_limit        17296
# type_of_application              0
# any_tax_liens                   11
# loan_paid                        0
# dtype: int64

# %%
dataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345310 entries, 0 to 345309
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        345310 non-null  int64
#  1   requested_amnt            345310 non-null  float64
#  2   loan_duration             345310 non-null  object
#  3   employment                323087 non-null  object
#  4   employment_length         324951 non-null  object
#  5   race                      345310 non-null  object
#  6   reason_for_loan           345310 non-null  object
#  7   extended_reason           341076 non-null  object
#  8   annual_income             345310 non-null  float64
#  9   debt_to_income_ratio      345214 non-null  float64
#  10  employment_verified       345310 non-null  object
#  11  public_bankruptcies       345129 non-null  float64
#  12  zipcode                   345310 non-null  object
# ...

# %%
# Out:
# ID                            int64
# requested_amnt              float64
# loan_duration                 int64
# employment                    int64
# employment_length             int64
# race                          int64
# reason_for_loan               int64
# extended_reason               int64
# annual_income               float64
# debt_to_income_ratio        float64
# employment_verified           int64
# public_bankruptcies          object
# zipcode                      object
# state                        object
# home_ownership_status        object
# delinquency_last_2yrs       float64
# fico_score_range_low        float64
# fico_score_range_high       float64
# fico_inquired_last_6mths    float64
# months_since_last_delinq    float64
# revolving_balance           float64
# total_revolving_limit       float64
# type_of_application          object
# any_tax_liens               float64
# loan_paid                    object
# dtype: object

# %%
#encode the dataSet
listNonNumeric = 'loan_duration','employment','employment_length','race','reason_for_loan','extended_reason','employment_verified','public_bankruptcies','zipcode','state','home_ownership_status','type_of_application'
for x in listNonNumeric: 
    dataSet[x] = dataSet[x].values.astype(str)
    dataSet[x] = dataSet[x].fillna('None')
    # Label encode ord_1 feature
    label_encoder = LabelEncoder()
    dataSet[x] = label_encoder.fit_transform(dataSet[x])
dataSet.head()
# Out:
#         ID  requested_amnt  loan_duration  employment  employment_length  \
# 0  1000000          9600.0              0       21526                 10
# 1  1000001          8000.0              0       97660                  6
# 2  1000002         21000.0              0       72045                  1
# 3  1000003          5000.0              0       48976                  2
# 4  1000004          3000.0              0       65979                 10
#
#    race  reason_for_loan  extended_reason  annual_income  \
# 0     4                2             5316        30000.0
# 1     1                2             5316        34500.0
# 2     1                9            11030        45000.0
# 3     1                1             4124        30000.0
# 4     1                9            11030        38000.0
#
#    debt_to_income_ratio  ...  delinquency_last_2yrs  fico_score_range_low  \
# 0                 19.01  ...                    0.0                 680.0
# ...

# %%
X = dataSet.loc[:, dataSet.columns != 'loan_paid']
y = dataSet['loan_paid']
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Out:
#              ID  requested_amnt loan_duration             employment  \
# 322318  1322318         10000.0     36 months  Firefighter paramedic
# 286168  1286168         22950.0     60 months                  owner
# 233043  1233043         15000.0     36 months      master instructer
# 76317   1076317         24000.0     36 months             Accountant
# 171598  1171598         16300.0     60 months                    NaN
# ...         ...             ...           ...                    ...
# 60841   1060841         19200.0     36 months               Manager
# 2547    1002547          8000.0     36 months   Coventry health care
# 274264  1274264         24250.0     60 months    St. Luke's Hospital
# 93110   1093110         35000.0     36 months                teacher
# 25665   1025665         13325.0     36 months                    NaN
#
#        employment_length race     reason_for_loan           extended_reason  \
# ...

# %%
clf_gbm = GradientBoostingClassifier()
clf_gbm.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-fd0a91358bcf> in <module>
#       1 clf_gbm = GradientBoostingClassifier()
# ----> 2 clf_gbm.fit(X_train, y_train)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py in fit(self, X, y, sample_weight, monitor)
#     560         # trees use different types for X and y, checking them separately.
#     561
# --> 562         X, y = self._validate_data(
#     563             X, y, accept_sparse=["csr", "csc", "coo"], dtype=DTYPE, multi_output=True
#     564         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     594                 y = check_array(y, input_name="y", **check_y_params)
#     595             else:
# --> 596                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
# Out:
# ...
#      |████████████████████████████████| 72 kB 983 kB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
